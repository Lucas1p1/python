# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout,Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/test'

# %%
import os

def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir, label)):
            image_paths.append(os.path.join(dir, label, imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label']= createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                 image     label
# 0            images/train\angry\0.jpg     angry
# 1            images/train\angry\1.jpg     angry
# 2           images/train\angry\10.jpg     angry
# 3        images/train\angry\10002.jpg     angry
# 4        images/train\angry\10016.jpg     angry
# ...                               ...       ...
# 28816  images/train\surprise\9969.jpg  surprise
# 28817  images/train\surprise\9985.jpg  surprise
# 28818  images/train\surprise\9990.jpg  surprise
# 28819  images/train\surprise\9992.jpg  surprise
# 28820  images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label']= createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
print(test['image'])
# Out:
#                               image     label
# 0       images/test\angry\10052.jpg     angry
# 1       images/test\angry\10065.jpg     angry
# 2       images/test\angry\10079.jpg     angry
# 3       images/test\angry\10095.jpg     angry
# 4       images/test\angry\10121.jpg     angry
# ...                             ...       ...
# 7061  images/test\surprise\9806.jpg  surprise
# 7062  images/test\surprise\9830.jpg  surprise
# 7063  images/test\surprise\9853.jpg  surprise
# 7064  images/test\surprise\9878.jpg  surprise
# 7065   images/test\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]
# 0         images/test\angry\10052.jpg
# 1         images/test\angry\10065.jpg
# 2         images/test\angry\10079.jpg
# 3         images/test\angry\10095.jpg
# 4         images/test\angry\10121.jpg
#                     ...
# 7061    images/test\surprise\9806.jpg
# 7062    images/test\surprise\9830.jpg
# 7063    images/test\surprise\9853.jpg
# 7064    images/test\surprise\9878.jpg
# ...

# %%
from tqdm.notebook import tqdm

# %%
import numpy as np

def extract_features(images):
    features = []  # Define features before using it
    for image in tqdm(images):
        img = load_img(image, grayscale=True)
        img = np.array(img)
        features.append(img)
    
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# C:\Users\Lucifer\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
model = Sequential()
#convolutional layers
model.add(Conv2D(128, kernel_size=(3,3),activation='relu',input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4 ))

model.add(Conv2D(128, kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))


model.add(Flatten())
#fully connected layers
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))          
model.add(Dropout(0.3))
#Output Layer
model.add(Dense(7, activation='softmax'))

# %%
from keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (28821,)
# (7066,)

# %%
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# %%
model.fit(x = x_train,y = y_train, batch_size = 128, epochs = 15, validation_data = (x_test,y_test))
# Out:
# Epoch 1/15
# 226/226 [==============================] - 768s 3s/step - loss: 1.8239 - accuracy: 0.2467 - val_loss: 1.8126 - val_accuracy: 0.2583
# Epoch 2/15
# 226/226 [==============================] - 725s 3s/step - loss: 1.8085 - accuracy: 0.2482 - val_loss: 1.8154 - val_accuracy: 0.2528
# Epoch 3/15
# 226/226 [==============================] - 519s 2s/step - loss: 1.7350 - accuracy: 0.2844 - val_loss: 1.6593 - val_accuracy: 0.3439
# Epoch 4/15
# 226/226 [==============================] - 387s 2s/step - loss: 1.6396 - accuracy: 0.3414 - val_loss: 1.5339 - val_accuracy: 0.3963
# Epoch 5/15
# 226/226 [==============================] - 380s 2s/step - loss: 1.5428 - accuracy: 0.3905 - val_loss: 1.4108 - val_accuracy: 0.4561
# Epoch 6/15
# 226/226 [==============================] - 399s 2s/step - loss: 1.4899 - accuracy: 0.4195 - val_loss: 1.3589 - val_accuracy: 0.4714
# Epoch 7/15
# ...

# %%
model_json = model.to_json()
with open("emotiondetector.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector.h5")
# Out:
# C:\Users\Lucifer\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import model_from_json

# %%
json_file = open("facialemotionmodel.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("facialemotionmodel.h5")

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
from keras.preprocessing import image
import numpy as np

def ef(image_path):
    img = image.load_img(image_path, grayscale=True, target_size=(48, 48))
    feature = np.array(img)
    feature = feature.reshape(1, 48, 48, 1)  # Add batch dimension and channel
    return feature / 255.0  # Normalize the pixel values

# Assuming 'model' is your trained model
image_path = 'images/train/angry/22.jpg'
print("Original image is of angry")
img = ef(image_path)

# Check the shape of the input before passing it to the model
print("Input shape:", img.shape)

pred = model.predict(img)
pred_label = label[pred.argmax()]
print("Model prediction is", pred_label)
# Out:
# Original image is of angry
# C:\Users\Lucifer\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\image_utils.py:409: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn(
# Input shape: (1, 48, 48, 1)
# 1/1 [==============================] - 15s 15s/step
# Model prediction is angry

# %%
from keras_preprocessing.image import load_img

def ef(image_path):
    img = load_img(image_path, grayscale=True, target_size=(48, 48))
    feature = np.array(img)
    feature = feature.reshape(1, 48, 48, 1)  # Add batch dimension and channel
    return feature

image = 'images/train/angry/22.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = le.classes_[pred.argmax()]  # Use le.classes_ to get the class labels
print("model prediction is", pred_label)
# Out:
# original image is of angry
# C:\Users\Lucifer\AppData\Local\Programs\Python\Python39\lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# 1/1 [==============================] - 0s 304ms/step
# model prediction is angry

# %%
# !pip install tf
# Out:
# ...
#   Created wheel for tf: filename=tf-1.0.0-py3-none-any.whl size=1293 sha256=dcc067f8c24d6ab5bb056d44fd7f012472ae768aad4194166100a5a0a1da9173
#   Stored in directory: c:\users\lucifer\appdata\local\pip\cache\wheels\92\d0\89\ab087968a762db2e1690a34d286cd41a3bd38ebeb3f99039d2
# Successfully built tf
# ...
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\users\lucifer\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as pit
# %matplotlib inline

# %%
image = 'images/train/sad/42.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is", pred_label)
plt.imshow(img.reshape(48, 48))
# Out:
# original image is of sad
# 1/1 [==============================] - 0s 39ms/step
# model prediction is fear

# %%
print(type(classifier).__name__)
# Out:
# RandomForestClassifier

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from keras.preprocessing import image as keras_image  # Rename 'image' to avoid conflict


# Evaluate the model on the test set
y_pred = model.predict(x_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true_labels, y_pred_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification Report
class_report = classification_report(y_true_labels, y_pred_labels, target_names=label)
print("\nClassification Report:")
print(class_report)
# Out:
# 221/221 [==============================] - 36s 164ms/step
# Confusion Matrix:
# [[ 465    9   40   64  183  174   25]
#  [  19   53    6    6    9   15    3]
#  [ 128   10  242   59  169  277  133]
#  [  41    3   21 1516  108   96   40]
#  [  60    1   21  109  781  223   21]
#  [  91    4   44   75  277  626   22]
#  [  14    1   51   50   43   18  620]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.57      0.48      0.52       960
#      disgust       0.65      0.48      0.55       111
#         fear       0.57      0.24      0.34      1018
#        happy       0.81      0.83      0.82      1825
#      neutral       0.50      0.64      0.56      1216
#          sad       0.44      0.55      0.49      1139
#     surprise       0.72      0.78      0.75       797
#
#     accuracy                           0.61      7066
#    macro avg       0.61      0.57      0.57      7066
# ...

# %%
# !pip install seaborn matplotlib
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\users\lucifer\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Assuming cm is your confusion matrix
cm = np.array([[465, 9, 40, 64, 183, 174, 25],
               [19, 53, 6, 6, 9, 15, 3],
               [128, 10, 242, 59, 169, 277, 133],
               [41, 3, 21, 1516, 108, 96, 40],
               [60, 1, 21, 109, 781, 223, 21],
               [91, 4, 44, 75, 277, 626, 22],
               [14, 1, 51, 50, 43, 18, 620]])

# Labels for each class
classes = ["Angry", "Disgust", "Fear", "Happy", "Neutral", "Sad", "Surprise"]

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index=classes, columns=classes)

# Plot the heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.2)
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues", cbar=False, linewidths=0.5, square=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'model' is your trained model and 'x_test', 'y_test' are your test data
num_samples = 5
indices = np.random.choice(len(x_test), num_samples, replace=False)

for i in indices:
    img = x_test[i].reshape(48, 48)
    true_label = label[np.argmax(y_test[i])]
    pred_label = label[np.argmax(model.predict(np.expand_dims(x_test[i], axis=0)))]

    plt.imshow(img, cmap='gray')
    plt.title(f'True: {true_label}\nPredicted: {pred_label}')
    plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 54ms/step

# %%
history = model.fit(x=x_train, y=y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 history = model.fit(x=x_train, y=y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3983, in Model._assert_compile_was_called(self)
#    3977 def _assert_compile_was_called(self):
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x=x_train, y=y_train, batch_size=128, epochs=15, validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 226/226 [==============================] - 1387s 6s/step - loss: 1.0177 - accuracy: 0.6155 - val_loss: 1.0715 - val_accuracy: 0.6043
# Epoch 2/15
# 226/226 [==============================] - 1607s 7s/step - loss: 1.0045 - accuracy: 0.6214 - val_loss: 1.0541 - val_accuracy: 0.6108
# Epoch 3/15
# 226/226 [==============================] - 1836s 8s/step - loss: 0.9992 - accuracy: 0.6278 - val_loss: 1.0483 - val_accuracy: 0.6114
# Epoch 4/15
# 226/226 [==============================] - 2470s 11s/step - loss: 0.9998 - accuracy: 0.6253 - val_loss: 1.0563 - val_accuracy: 0.6132
# Epoch 5/15
# 103/226 [============>.................] - ETA: 21:54 - loss: 0.9887 - accuracy: 0.6283
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[105], line 2
#       1 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# ...

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score

# Assuming 'model' is your trained model

# Convert labels to one-hot encoding
y_test_one_hot = label_binarize(y_test.argmax(axis=1), classes=list(range(7)))

# Predict probabilities for each class
y_score = model.predict(x_test)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_test_one_hot[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure(figsize=(10, 8))
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
for i, color in zip(range(7), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve (class {i}) (area = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# 221/221 [==============================] - 54s 187ms/step

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'model' is your RandomForestClassifier
# You need to replace RandomForestClassifier with your actual model if it's different

# Fit the model with training data
model.fit(x_train.reshape(x_train.shape[0], -1), y_train.argmax(axis=1))

# Convert labels to one-hot encoding
y_test_one_hot = label_binarize(y_test.argmax(axis=1), classes=list(range(7)))

# Predict probabilities for each class
y_score = model.predict_proba(x_test.reshape(x_test.shape[0], -1))

# Compute precision and recall for each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(7):
    precision[i], recall[i], _ = precision_recall_curve(y_test_one_hot[:, i], y_score[:, i])
    average_precision[i] = average_precision_score(y_test_one_hot[:, i], y_score[:, i])

# Plot Class-wise Precision and Recall Bar Chart
classes = [f'Class {i}' for i in range(7)]
precision_values = [precision_score(y_test_one_hot[:, i], (y_score[:, i] > 0.5).astype(int)) for i in range(7)]
recall_values = [recall_score(y_test_one_hot[:, i], (y_score[:, i] > 0.5).astype(int)) for i in range(7)]

bar_width = 0.35
index = np.arange(len(classes))

plt.bar(index, precision_values, bar_width, label='Precision')
plt.bar(index + bar_width, recall_values, bar_width, label='Recall')

plt.xlabel('Class')
plt.ylabel('Score')
plt.title('Class-wise Precision and Recall')
plt.xticks(index + bar_width / 2, classes)
plt.legend()

plt.show()
